# %% [markdown]
# <a href="https://colab.research.google.com/github/RohanBurad/Python-Programming/blob/main/02_Logic_Challenge/Level_1_Loops%2C%20Math%20Logic%2C%20and%20List%20Comprehensions/01_Prime_Number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task - 01**
#
# **Write a Function to check if a number is Prime or Not**

# %%
#   Function for Checking Prime Number
def check_prime(n):
  if n <= 1:
    return (f"{n} is not a Prime Number")

  for i in range(2,int(n**0.5+1)):
    if n % i == 0:
      return (f"{n} is not a Prime Number.")1
    else:
      return (f"{n} is Prime Number.")
number = int(input("Enter the Number for Check : "))
check_prime(number)
# Out:
# Enter the Number for Check : 19
# '19 is Prime Number.'
